# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammedayman/full/blob/master/pp25_hundredpercentage_success.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Mar  8 04:06:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# '2nd floor sabre asset.gsheet'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-GroundServicesv1.3.xlsx'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-Hotels.xlsx'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-Transportation v1.3.xlsx'
# '5 adult 4m 1f.mp4'
#  5adults4m1f.mp4
# 'akbar assets'
# 'ATTENDANCE FORMAT (1).gsheet'
# 'ATTENDANCE FORMAT (1).xlsx'
# 'ATTENDANCE FORMAT (2).xlsx'
# 'ATTENDANCE FORMAT.gsheet'
# 'ATTENDANCE FORMAT.xlsx'
# 'BRANCH ADRESS PAN INDIA- 2020.gsheet'
# 'BRANCH ADRESS PAN INDIA- 2020.xls'
# 'CCTV Details Updated - 5.2.19 (1).gsheet'
# 'CCTV Details Updated - 5.2.19.gsheet'
# 'CCTV Details Updated - 9.2.19 .gsheet'
# 'Colab Notebooks'
# 'Copy of CCTV Details Updated - 9.2.19 .gsheet'
#  CRS
#  Details.gsheet
# 'IP HO VISA ONLINE.gsheet'
#  jpgg.jpg
# 'laptop details.gsheet'
# 'laptop xs (1).gsheet'
# 'laptop xs.gsheet'
# 'laptop xs.xlsx'
# 'mqam api test'
# 'New Akbar Token.txt'
#  officestd2010.rar
# ...

# %%
# !ls /mydrive
# Out:
# '2nd floor sabre asset.gsheet'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-GroundServicesv1.3.xlsx'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-Hotels.xlsx'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-Transportation v1.3.xlsx'
# '5 adult 4m 1f.mp4'
#  5adults4m1f.mp4
# 'akbar assets'
# 'ATTENDANCE FORMAT (1).gsheet'
# 'ATTENDANCE FORMAT (1).xlsx'
# 'ATTENDANCE FORMAT (2).xlsx'
# 'ATTENDANCE FORMAT.gsheet'
# 'ATTENDANCE FORMAT.xlsx'
# 'BRANCH ADRESS PAN INDIA- 2020.gsheet'
# 'BRANCH ADRESS PAN INDIA- 2020.xls'
# 'CCTV Details Updated - 5.2.19 (1).gsheet'
# 'CCTV Details Updated - 5.2.19.gsheet'
# 'CCTV Details Updated - 9.2.19 .gsheet'
# 'Colab Notebooks'
# 'Copy of CCTV Details Updated - 9.2.19 .gsheet'
#  CRS
#  Details.gsheet
# 'IP HO VISA ONLINE.gsheet'
#  jpgg.jpg
# 'laptop details.gsheet'
# 'laptop xs (1).gsheet'
# 'laptop xs.gsheet'
# 'laptop xs.xlsx'
# 'mqam api test'
# 'New Akbar Token.txt'
#  officestd2010.rar
# 'On duty form.gsheet'
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14730, done.
# remote: Total 14730 (delta 0), reused 0 (delta 0), pack-reused 14730
# Receiving objects: 100% (14730/14730), 13.27 MiB | 24.36 MiB/s, done.
# Resolving deltas: 100% (10020/10020), done.

# %%
# !ls
# %cd darknet/
# !ls
# Out:
# darknet  gdrive  sample_data
# /content/darknet
# 3rdparty	DarknetConfig.cmake.in	include		       results
# build		darknet_images.py	json_mjpeg_streams.sh  scripts
# build.ps1	darknet.py		LICENSE		       src
# build.sh	darknet_video.py	Makefile	       vcpkg.json
# cfg		data			net_cam_v3.sh	       video_yolov3.sh
# cmake		image_yolov3.sh		net_cam_v4.sh	       video_yolov4.sh
# CMakeLists.txt	image_yolov4.sh		README.md

# %%
#%cd /content/gdrive/MyDrive/yolov3pp25/darknet

# %%
#%cd ../
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       results
# build		darknet_images.py	json_mjpeg_streams.sh  scripts
# build.ps1	darknet.py		LICENSE		       src
# build.sh	darknet_video.py	Makefile	       vcpkg.json
# cfg		data			net_cam_v3.sh	       video_yolov3.sh
# cmake		image_yolov3.sh		net_cam_v4.sh	       video_yolov4.sh
# CMakeLists.txt	image_yolov4.sh		README.md

# %%
#!cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !cp /content/gdrive/MyDrive/yolov3pp25/yolov3_training.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !sed -i 's/batch=2/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/width=738/width=416/' cfg/yolov3_training.cfg
# !sed -i 's/height=519/height=416/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=2/subdivisions=64/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 50000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=25@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=25@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=25@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=90@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=90@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=90@' cfg/yolov3_training.cfg

# %%
# !mkdir /mydrive/yolov3pp25
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov3pp25’: File exists

# %%
#%cd data/
#%cd data/obj.data
# !ls

# %%
# !echo -e  passportno "\npassportno_lbl\npoi\npoi_lbl\ndoi\ndoi_lbl\npob\npob_lbl\ndob\ndob_lbl\ndoe\ndoe_lbl\nnationality\nnationality_lbl\ncountrycode\ncountrycode_lbl\nsurname\nsurname_lbl\ngivenname\ngivenname_lbl\nsex\nsex_lbl\nphoto\nsignature\nmrz" > data/obj.names


# !echo -e 'classes= 25\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3pp25' > data/obj.data
# !mkdir data/obj

# %%
# !cp  data/obj.names /content/gdrive/MyDrive/yolov3pp25/obj.names
# !cp  cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3pp25/yolov3_training.cfg

# %%
# !cp  cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3pp25/yolov3_training.cfg

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-03-08 04:36:48--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  91.8MB/s    in 1.7s
#
# 2021-03-08 04:36:50 (91.8 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !cp -r /mydrive/yolov3pp25/passport/ -d data/obj

# %%
import glob
import os
import re
images_list=glob.glob('data/obj/passport/*.jpg')
print(images_list)
# Out:
# ['data/obj/passport/aa (167).jpg', 'data/obj/passport/aa (264).jpg', 'data/obj/passport/aa (109).jpg', 'data/obj/passport/aa (366).jpg', 'data/obj/passport/aa (374).jpg', 'data/obj/passport/aa (62).jpg', 'data/obj/passport/aa (196).jpg', 'data/obj/passport/aa (163).jpg', 'data/obj/passport/aa (425).jpg', 'data/obj/passport/aa (427).jpg', 'data/obj/passport/aa (408).jpg', 'data/obj/passport/aa (145).jpg', 'data/obj/passport/aa (52).jpg', 'data/obj/passport/aa (270).jpg', 'data/obj/passport/aa (404).jpg', 'data/obj/passport/aa (111).jpg', 'data/obj/passport/PP1.jpg', 'data/obj/passport/aa (376).jpg', 'data/obj/passport/aa (204).jpg', 'data/obj/passport/Image (198).jpg', 'data/obj/passport/aa (339).jpg', 'data/obj/passport/biji.jpg', 'data/obj/passport/aa (13).jpg', 'data/obj/passport/aa (431).jpg', 'data/obj/passport/aa (272).jpg', 'data/obj/passport/aa (103).jpg', 'data/obj/passport/aa (214).jpg', 'data/obj/passport/aa (406).jpg', 'data/obj/passport/anwarsadath pp1.jpg', 'data/obj/pas
# ...

# %%
file=open('data/train.txt','w')
file.write("\n".join(images_list))
file.close()

# %%
with open('cfg/yolov3_training.cfg', 'r') as f:
  for line in f:
    print(line)
# Out:
# [net]
#
# # Testing
#
# #batch=64
#
# #subdivisions=26666
#
# # Training
#
# batch=64
#
# subdivisions=2
#
# width=416
#
# height=416
#
# channels=3
#
# momentum=0.9
#
# decay=0.0005
#
# angle=0
#
# saturation = 1.5
#
# exposure = 1.5
#
# hue=.1
#
#
#
# learning_rate=0.001
#
# burn_in=1000
#
# max_batches = 50000
#
# policy=steps
#
# steps=40000,45000
#
# scales=.1,.1
#
#
#
# [convolutional]
#
# batch_normalize=1
#
# filters=32
#
# size=3
#
# stride=1
#
# pad=1
#
# activation=leaky
#
#
#
# # Downsample
#
#
#
# [convolutional]
#
# batch_normalize=1
#
# filters=64
#
# size=3
#
# stride=2
#
# pad=1
#
# activation=leaky
#
#
#
# [convolutional]
#
# batch_normalize=1
#
# filters=32
#
# size=1
#
# stride=1
#
# pad=1
#
# activation=leaky
#
#
#
# [convolutional]
#
# batch_normalize=1
#
# filters=64
#
# size=3
#
# stride=1
#
# pad=1
#
# activation=leaky
#
#
#
# [shortcut]
#
# from=-3
#
# activation=linear
#
#
#
# # Downsample
#
#
#
# [convolutional]
#
# batch_normalize=1
#
# filters=128
#
# ...

# %%
with open('data/train.txt', 'r') as f:
  for line in f:
    print(line)
# Out:
# data/obj/passport/aa (167).jpg
#
# data/obj/passport/aa (264).jpg
#
# data/obj/passport/aa (109).jpg
#
# data/obj/passport/aa (366).jpg
#
# data/obj/passport/aa (374).jpg
#
# data/obj/passport/aa (62).jpg
#
# data/obj/passport/aa (196).jpg
#
# data/obj/passport/aa (163).jpg
#
# data/obj/passport/aa (425).jpg
#
# data/obj/passport/aa (427).jpg
#
# data/obj/passport/aa (408).jpg
#
# data/obj/passport/aa (145).jpg
#
# data/obj/passport/aa (52).jpg
#
# data/obj/passport/aa (270).jpg
#
# data/obj/passport/aa (404).jpg
#
# data/obj/passport/aa (111).jpg
#
# data/obj/passport/PP1.jpg
#
# data/obj/passport/aa (376).jpg
#
# data/obj/passport/aa (204).jpg
#
# data/obj/passport/Image (198).jpg
#
# data/obj/passport/aa (339).jpg
#
# data/obj/passport/biji.jpg
#
# data/obj/passport/aa (13).jpg
#
# data/obj/passport/aa (431).jpg
#
# data/obj/passport/aa (272).jpg
#
# data/obj/passport/aa (103).jpg
#
# data/obj/passport/aa (214).jpg
#
# data/obj/passport/aa (406).jpg
#
# ...

# %%
with open('data/obj.names', 'r') as f:
  for line in f:
    print(line)
# Out:
# passportno
#
# passportno_lbl
#
# poi
#
# poi_lbl
#
# doi
#
# doi_lbl
#
# pob
#
# pob_lbl
#
# dob
#
# dob_lbl
#
# doe
#
# doe_lbl
#
# nationality
#
# nationality_lbl
#
# countrycode
#
# countrycode_lbl
#
# surname
#
# surname_lbl
#
# givenname
#
# givenname_lbl
#
# sex
#
# sex_lbl
#
# photo
#
# signature
#
# mrz

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3pp25/yolov3_training_last.weights -dont_show
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3ppbb12/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 4488961, rewritten_bbox = 0.625891 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.817470), count: 2, class_loss = 0.009405, iou_loss = 0.119783, total_loss = 0.129188
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.881294), count: 10, class_loss = 0.003720, iou_loss = 0.540519, total_loss = 0.544239
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.834650), count: 13, class_loss = 1.496598, iou_loss = 1.067650, total_loss = 2.564248
#  total_bbox = 4488986, rewritten_bbox = 0.625887 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.936674), count: 1, class_loss = 0.000053, iou_loss = 0.006156, total_loss = 0.006209
# ...
