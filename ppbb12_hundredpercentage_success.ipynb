# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammedayman/full/blob/master/ppbb12_hundredpercentage_success.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive /mydrive
# !ls /mydrive

# %%
# !ls /mydrive
# Out:
# '2nd floor sabre asset.gsheet'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-GroundServicesv1.3.xlsx'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-Hotels.xlsx'
# '3. OTAtoGDS_Certification Scenarios and Test-cases-Transportation v1.3.xlsx'
# '5 adult 4m 1f.mp4'
#  5adults4m1f.mp4
# 'akbar assets'
# 'ATTENDANCE FORMAT (1).gsheet'
# 'ATTENDANCE FORMAT (1).xlsx'
# 'ATTENDANCE FORMAT (2).xlsx'
# 'ATTENDANCE FORMAT.gsheet'
# 'ATTENDANCE FORMAT.xlsx'
# 'BRANCH ADRESS PAN INDIA- 2020.gsheet'
# 'BRANCH ADRESS PAN INDIA- 2020.xls'
# 'CCTV Details Updated - 5.2.19 (1).gsheet'
# 'CCTV Details Updated - 5.2.19.gsheet'
# 'CCTV Details Updated - 9.2.19 .gsheet'
# 'Colab Notebooks'
# 'Copy of CCTV Details Updated - 9.2.19 .gsheet'
#  CRS
#  Details.gsheet
# 'IP HO VISA ONLINE.gsheet'
#  jpgg.jpg
# 'laptop details.gsheet'
# 'laptop xs (1).gsheet'
# 'laptop xs.gsheet'
# 'laptop xs.xlsx'
# 'mqam api test'
# 'New Akbar Token.txt'
#  officestd2010.rar
# 'On duty form.gsheet'
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14730, done.
# remote: Total 14730 (delta 0), reused 0 (delta 0), pack-reused 14730
# Receiving objects: 100% (14730/14730), 13.27 MiB | 24.71 MiB/s, done.
# Resolving deltas: 100% (10020/10020), done.

# %%
# !ls
# %cd darknet/
# !ls
# Out:
# darknet  gdrive  sample_data
# /content/darknet
# 3rdparty	DarknetConfig.cmake.in	include		       results
# build		darknet_images.py	json_mjpeg_streams.sh  scripts
# build.ps1	darknet.py		LICENSE		       src
# build.sh	darknet_video.py	Makefile	       vcpkg.json
# cfg		data			net_cam_v3.sh	       video_yolov3.sh
# cmake		image_yolov3.sh		net_cam_v4.sh	       video_yolov4.sh
# CMakeLists.txt	image_yolov4.sh		README.md

# %%
#%cd /content/gdrive/MyDrive/yolov3pp25/darknet

# %%
#%cd ../
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       results
# build		darknet_images.py	json_mjpeg_streams.sh  scripts
# build.ps1	darknet.py		LICENSE		       src
# build.sh	darknet_video.py	Makefile	       vcpkg.json
# cfg		data			net_cam_v3.sh	       video_yolov3.sh
# cmake		image_yolov3.sh		net_cam_v4.sh	       video_yolov4.sh
# CMakeLists.txt	image_yolov4.sh		README.md

# %%
#!cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !cp /content/gdrive/MyDrive/yolov3ppbb12/yolov3_training.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !sed -i 's/batch=64/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/width=738/width=416/' cfg/yolov3_training.cfg
# !sed -i 's/height=519/height=416/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=16/subdivisions=64/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 24000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=12@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=12@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=12@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=51@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=51@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=51@' cfg/yolov3_training.cfg

# %%
# !mkdir /mydrive/yolov3ppbb12
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov3ppbb12’: File exists

# %%
#%cd data/
#%cd data/obj.data
# !ls

# %%
# !echo -e  guardian_lbl "\nguardian\nmother_lbl\nmother\nspouse_lbl\nspouse\naddress_lbl\naddress\nold_passport_lbl\nold_passport\nfile_lbl\nfile" > data/obj.names


# !echo -e 'classes= 12\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3ppbb12' > data/obj.data
# !mkdir data/obj

# %%
# !cp  data/obj.names /content/gdrive/MyDrive/yolov3ppbb12/obj.names
# !cp  cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3ppbb12/yolov3_training.cfg

# %%
# !cp  cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3ppbb12/yolov3_training.cfg

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-03-01 06:10:43--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  42.4MB/s    in 4.0s
#
# 2021-03-01 06:10:48 (39.1 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
# !cp -r /mydrive/yolov3ppbb12/passport/ -d data/obj

# %%
import glob
import os
import re
images_list=glob.glob('data/obj/passport/*.jpg')
print(images_list)
# Out:
# ['data/obj/passport/aa (221).jpg', 'data/obj/passport/U9489390 PPLAST.jpg', 'data/obj/passport/aa (29).jpg', 'data/obj/passport/T4223188 PPLAST.jpg', 'data/obj/passport/aa (134).jpg', 'data/obj/passport/aa (318).jpg', 'data/obj/passport/aa (403).jpg', 'data/obj/passport/aa (385).jpg', 'data/obj/passport/T1262199 PPLAST.jpg', 'data/obj/passport/aa (277).jpg', 'data/obj/passport/aa (284).jpg', 'data/obj/passport/aa (39).jpg', 'data/obj/passport/aa (286).jpg', 'data/obj/passport/aa (344).jpg', 'data/obj/passport/aa (393).jpg', 'data/obj/passport/aa (269).jpg', 'data/obj/passport/U5241456 PPLAST.jpg', 'data/obj/passport/aa (251).jpg', 'data/obj/passport/U2747419 PPLAST.jpg', 'data/obj/passport/Z3567311 PPLASTCopy-0d68d0d09852495788ce16efa8a7b953.jpg', 'data/obj/passport/U8329391 PPLAST.jpg', 'data/obj/passport/aa (357).jpg', 'data/obj/passport/aa (414).jpg', 'data/obj/passport/U7689017 PPLAST.jpg', 'data/obj/passport/aa (405).jpg', 'data/obj/passport/aa (35).jpg', 'data/obj/passport/aa (
# ...

# %%
file=open('data/train.txt','w')
file.write("\n".join(images_list))
file.close()

# %%
with open('cfg/yolov3_training.cfg', 'r') as f:
  for line in f:
    print(line)

# %%
with open('data/obj.names', 'r') as f:
  for line in f:
    print(line)

# %%
with open('data/train.txt', 'r') as f:
  for line in f:
    print(line)
# Out:
# data/obj/passport/aa (221).jpg
#
# data/obj/passport/U9489390 PPLAST.jpg
#
# data/obj/passport/aa (29).jpg
#
# data/obj/passport/T4223188 PPLAST.jpg
#
# data/obj/passport/aa (134).jpg
#
# data/obj/passport/aa (318).jpg
#
# data/obj/passport/aa (403).jpg
#
# data/obj/passport/aa (385).jpg
#
# data/obj/passport/T1262199 PPLAST.jpg
#
# data/obj/passport/aa (277).jpg
#
# data/obj/passport/aa (284).jpg
#
# data/obj/passport/aa (39).jpg
#
# data/obj/passport/aa (286).jpg
#
# data/obj/passport/aa (344).jpg
#
# data/obj/passport/aa (393).jpg
#
# data/obj/passport/aa (269).jpg
#
# data/obj/passport/U5241456 PPLAST.jpg
#
# data/obj/passport/aa (251).jpg
#
# data/obj/passport/U2747419 PPLAST.jpg
#
# data/obj/passport/Z3567311 PPLASTCopy-0d68d0d09852495788ce16efa8a7b953.jpg
#
# data/obj/passport/U8329391 PPLAST.jpg
#
# data/obj/passport/aa (357).jpg
#
# data/obj/passport/aa (414).jpg
#
# data/obj/passport/U7689017 PPLAST.jpg
#
# data/obj/passport/aa (405).jpg
#
# data/obj/passport/aa (35).jpg
#
# ...

# %%
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3pp25/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 2171162, rewritten_bbox = 1.256885 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.842994), count: 6, class_loss = 0.000006, iou_loss = 0.238036, total_loss = 0.238041
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.809224), count: 2, class_loss = 0.011527, iou_loss = 0.219239, total_loss = 0.230766
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.849594), count: 4, class_loss = 0.004860, iou_loss = 0.209897, total_loss = 0.214757
#  total_bbox = 2171174, rewritten_bbox = 1.256878 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.854747), count: 5, class_loss = 0.000081, iou_loss = 0.345227, total_loss = 0.345308
# ...
